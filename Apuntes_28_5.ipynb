# %% [markdown]
# <a href="https://colab.research.google.com/github/viche09cpsn/mi-primer-repositorio/blob/main/Apuntes_28_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class TarjetaCredito:
  def __init__(self, banco, limite):
    self.banco = banco
    self.limite = limite
  def mostrar_limite(self):
    print(f"Tarjeta de {self.banco} con limite de ${self.limite}")

class UsuarioConTarjeta:
  def __init__(self, nombre, tarjeta):
    self.nombre = nombre
    self.tarjeta = tarjeta

  def mostrar_tarjeta(self):
    print(f"Usuario: {self.nombre}")
    self.tarjeta.mostrar_limite()

mi_tarjeta = TarjetaCredito("Banco Demo", 100000)
usuario = UsuarioConTarjeta("Ana", mi_tarjeta)
usuario.mostrar_tarjeta()
print("\n")
mi_tarjeta = TarjetaCredito("Aguilar Bank Holdings plc", 10000000)
usuario = UsuarioConTarjeta("Masi", mi_tarjeta)
usuario.mostrar_tarjeta()
# Out:
# Usuario: Ana
# Tarjeta de Banco Demo con limite de $100000
#
#
# Usuario: Masi
# Tarjeta de Aguilar Bank Holdings plc con limite de $10000000
